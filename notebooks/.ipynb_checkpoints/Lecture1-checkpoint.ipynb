# %% [markdown]
# ## Lecture Notes

# %% [markdown]
# ### Signal Classification
#
# **Univariate**
# Signals where only one variable is measured from a system. Example: Temperature or pressure.
# Notationy=f(x) where input is a scalar and output is a scalar
#
# **Multivariate**
# Signals where multiple variable are measured, Example: Both pressure and a temperature.
# Notation: x, y = f(a,b) where input is a vector and output is a vector
#
# **Multidimensional**
# A single signal, made up og several signals. Example: A greyscale picture where the input is the dimensions m,n and the output a value from 0-255
# Notation y = f(a,b) where vector is a vector and output is a vector

# %% [markdown]
# ### Randomness
#
# The lack of complete knowledge/mathematical function of a system. The actual system might not be random, but a limited knowledge might be modelled a randomness.
# Example: In weather forecasting, wind speed depends on the atmosphere which is a complex system. We don't model that but treat it as random even thought it might not be random.
#
# Can either be: Uncertainty in in process knowledge or uncertainty in measurements.

# %% [markdown]
# ### Stochastic signal
#
# Given an **ensample**(stochastic process), multiple runs/experiments will most likely yields different **realizations**(outcomes). Example: ¤ tosses of a fair coin.
#
# **Key Challenge**
# Estimating or inferring the stochastic process parameters from a single realization of a process.

# %% [markdown]
# ### Processing examples
#
# **Estimation**
# Estimate parameters such as phase, amplitude, mean etc.
#
# **Classfication**
# What process is this signal comming from
#
# **Regression**
# Given an unseen input value, what is the output value.
#
# **Forecasting**
# What is the next N values going to be?
#
# **Signal esimation(De-noising)**
# Estimate the true value of the signal. Remove noise

# %% [markdown]
# ### Modelling
#
# **Model**
#
# Approximate model that explains the behaviour of a physical system
#
# **Modelling process**
#
# We start with a hyphotesis and perform an experiment. Then the model is refined until the outcome of the model is approximately the same as the outcome
# of the experiement on the physical system.
#
# ![stochastic_model.png](attachment:12c6b347-7753-49a6-8bcc-b6640ed45f4a.png)

# %% [markdown]
# ### Random Variables and PDF
#
# **Random variable**
#
# A function that assigns a number to each outcome of a random experiment
#
# **Probability Density Function(PDF)**
#
# A fuction that assigns a probability to each of the numbers the random variable can take

# %% [markdown]
# ### Statistical Regularity
#
# How do we assign probabilities to each out come? The answer is **statistical regularity**.
# When an an experiment is performed many times, a pattern will develop. That is statistical regularity.
# Example: Tossing a fair dice an N times, we will see that we get each side up approximately N/6 times as long as N is large.
#
# If $ N_0(n) $ and $ N_1(n) $ is the number of times we get heads an tails respectively in n trials. We define the relative frequency as
# $$
# f_k(n)=\frac{N_k(n)}{N}
# $$
#
# Then statisctical regularity implies that
#
# $$
# \lim_{n \to \infty} f_k(n)=p_k
# $$

# %% [markdown]
# ### Sample Space
#
# The sample space is all the possible outcomes of an experiment and is commonly denoted as $ \Omega $, $U$ or $S$
#
# Here is some expamples of the sample space:
#
# Toss of fair dice: $ \S = \{ 1,2,3,4,5,6 \}$
# Toss of fair coin: $ \S = \{ Head, Tail\} $

# %% [markdown]
# ### Foundational Probability Axioms (Kolmogorov’s Axioms)
#
# Let $ \Omega $ be the sample space, and $ P $ a probability measure on subsets of $ \Omega $. Then:
#
#
# #### 1. Non-negativity
# For any event $ A \subseteq \Omega $:
# $$
# P(A) \geq 0
# $$
#
# Here $ A \subseteq  \Omega$ is read as: "$A$ is a subset of $\Omega$"
#
#
# #### 2. Normalization (Unit Measure)
# The probability of the entire sample space is:
# $$
# P(\Omega) = 1
# $$
#
#
# #### 3. Countable Additivity (σ-additivity)
# For any countable sequence of mutually disjoint events
# $ A_1, A_2, A_3, \dots $ (i.e., $ A_i \cap A_j = \varnothing $ for $ i \neq j $):
#
# $$
# P\!\left(\bigcup_{i=1}^{\infty} A_i\right)
# = \sum_{i=1}^{\infty} P(A_i)
# $$
#
# Events are mutually disjoint is they cannot happen at the same time.
# For example, a coin toss has events $A_1=\{Head\}$ and $A_2=\{Tail\}$. These events are mutually disjoint since they cannot happen at the same time.
#
#
# From these three axioms, all other probability rules can be derived (e.g.,
# $
# P(A^c) = 1 - P(A)
# $, inclusion–exclusion, etc.).

# %% [markdown]
# ## Problems

# %% [markdown]
# ### Problem 1.7
#
# **Problem**
#
# Let A be an event associated with outcomes of a random experiment, and let the event B
# be defined as “event A does not occur.” Show that $f_B(n)=1-f_A(n)$
#
# **Solution**
#
# Let $B = \overline{A}$
#
# We define the sample space as $\Omega = A \cup B = A \cup \overline{A}$
#
# From the problem statement we know that $A \cup \overline{A} = \emptyset$ where $\emptyset$ is the empty set and that $P(A \cap  \overline{A}) = 0$
#
# From probability axioms we have
#
# Countable additivity:
# $P(A \cup \overline{A}) = P(A) + P(\overline{A}) $ since they are mutually disjoint
#
# Normalization:
# $P(\Omega)=P(A \cup \overline{A})=1$ since the probability of the total sample space has to equal one.
#
# Hence: $P(A \cup \overline{A}) = P(A) + P(\overline{A}) = 1$
# And: $P(\overline{A})= P(B)=1 - P(A)$

# %% [markdown]
# ### Problem 1.8
#
# **Problem**
#
# Let A, B, and C be events that cannot occur simultaneously as pairs or triplets, and let D
# be the event “A or B or C occurs.” Show that
#
# $
# f_D(n)=f_A(n)+f_B(n)+f_C(n)
# $
#
# **Solution**
#
# We define $ D = A \cup B \cup C$
#
# From the probability axioms we have:
#
# Countable additivity:
# Since the events $A$, $B$ and $C$ are mutually disjoint events, we know that
#
# $$
# P(D) = P(A \cup B \cup C) = P(A) + P(B) + P(C)
# $$

# %% [markdown]
# ### Problem 1.9
#
# **Problem**
#
# The sample mean for a series of numerical outcomes of a sequence of random experiments is defined by
#
# $$
# \bar{X} = \frac{1}{n} \sum_{j=1}^{n} X_j
# $$
#
# Show that the sample mean satisfies the recursion formula:
#
# $$
# \bar{X}_{n} = \bar{X}_{n-1} + \frac{X_n-\bar{X}_{n-1}}{n}
# $$
#
# Where $\bar{X}_{0}=0$
#
# **Solution**
#
# We rewrite
#
# $$
# \bar{X} = \frac{1}{n} \sum_{j=1}^{n} X_i = \frac{1}{n} (\sum_{j=1}^{n-1} X_j + X_n)
# $$
#
# To obtain $\bar{X}_{n-1}$ in the expanded term, we multiply by $\frac{n-1}{n-1}$
#
#
# $$
# \bar{X} = \frac{1}{n} \frac{n-1}{n-1} (\sum_{j=1}^{n-1} X_j + X_n) = \frac{n-1}{n} (\frac{1}{n-1}\sum_{j=1}^{n-1} X_j + \frac{1}{n-1}X_n)
# $$
#
# Since $\bar{X}_{n-1}=\frac{1}{n-1}\sum_{j=1}^{n-1} X_j$
#
# $$
# \bar{X} = \frac{n-1}{n} (\bar{X}_{n-1} + \frac{1}{n-1}X_n) = \frac{n\bar{X}_{n-1}-\bar{X}_{n-1}}{n} + \frac{X_n}{n}= \bar{X}_{n-1} + \frac{X_n-\bar{X}_{n-1}}{n}
# $$

# %% [markdown]
# ### Problem 1.10
#
# **Problem**
#
# Suppose that the signal $2cos(2\pi t)$ is sampled at random instants of time.
# **(a)** Find the long-term sample mean.
# **(b)** Find the long-term relative frequency of the events “voltage is positive”; “voltage is
# less than -2”
# **(c)** Do the answers to parts a and b change if the sampling times are periodic and taken
# every $\tau$ seconds?
#
#
# **Solution**
#
# **(a)**
#
#
# We define the random varible $T$ to be uniformly distributed between $0$ and $1$ since the period of the signal is 1.
#
# Then we define the random variable $X=2cos(2 \pi T)$
#
# From definition
#
# $$
# \mathbb{E}[X] = \int_{-\infty}^{\infty} x \, f_X(x) \, dx
# $$
#
# Since $X$ is uniformly distributed from 0 to 1, $f_X(x) = 1$ and the expectation becomes
#
# $$
# \mathbb{E}[X]=\int_0^1 2 \cos(2 \pi t) \, dt = 0
# $$
#
# **(b)**
#
# Since mean is 0, and cosine oscillates around the mean, the relative frequency is $\frac{1}{2}$
